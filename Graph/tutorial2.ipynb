# %%
import seaborn as sns

# %% [markdown]
# # Data Visualization with Seaborn, Matplotlib, and Plotly
# This notebook demonstrates how to use Seaborn, Matplotlib, and Plotly for data visualization and analysis. Each code cell is preceded by a markdown cell explaining its purpose and usage with examples.
#
# ## Importing Seaborn
# Seaborn is a powerful Python library for statistical data visualization built on top of matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# **Example:**
# ```python
# import seaborn as sns
# ```

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Loading the Iris Dataset
# Seaborn provides built-in datasets for practice and demonstration. Here, we load the famous Iris dataset, which contains measurements of iris flowers from three different species.
# **Example:**
# ```python
# df = sns.load_dataset('iris')
# df.head()  # Display the first few rows
# ```

# %%
sns.scatterplot(df,x='sepal_length',y='petal_length',hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ## Scatter Plot with Seaborn
# A scatter plot visualizes the relationship between two numerical variables. The `hue` parameter colors the points by species, making it easy to distinguish between different classes.
# **Example:**
# ```python
# sns.scatterplot(df, x='sepal_length', y='petal_length', hue='species')
# ```
# - Each point represents a flower sample.
# - Colors indicate the species.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Matplotlib
# Matplotlib is a foundational plotting library in Python. Seaborn is built on top of matplotlib and often requires it for advanced customization.
# **Example:**
# ```python
# import matplotlib.pyplot as plt
# ```

# %%
plt.plot(df.sepal_length,df.petal_length,'o')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
# Out:
# Text(0, 0.5, 'Petal Length')

# %% [markdown]
# ## Scatter Plot with Matplotlib
# This code creates a scatter plot using matplotlib to visualize the relationship between sepal length and petal length.
# **Example:**
# ```python
# plt.plot(df.sepal_length, df.petal_length, 'o')
# plt.xlabel('Sepal Length')
# plt.ylabel('Petal Length')
# plt.show()
# ```
# - `'o'` specifies circle markers for each data point.

# %%
plt.hist(df['sepal_length'],alpha=0.5)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Histogram of Sepal Length
# A histogram shows the distribution of a numerical variable by dividing the data into bins and displaying the frequency of values in each bin.
# **Example:**
# ```python
# plt.hist(df['sepal_length'], alpha=0.5)
# plt.xlabel('Sepal Length')
# plt.ylabel('Frequency')
# plt.show()
# ```
# - `alpha=0.5` sets the transparency of the bars.

# %%
sns.distplot(df['sepal_length'])
# Out:
# C:\Users\haida\AppData\Local\Temp\ipykernel_15396\537145680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# ## Distribution Plot with Seaborn
# A distribution plot (distplot) shows the distribution of a numerical variable as a combination of a histogram and a kernel density estimate (KDE).
# **Example:**
# ```python
# sns.distplot(df['sepal_length'])
# ```
# - Shows both the histogram and a smooth curve representing the data distribution.
# - Note: In recent versions of seaborn, use `sns.histplot` or `sns.kdeplot` instead.

# %%
df1 = sns.load_dataset('tips')

# %% [markdown]
# ## Loading the Tips Dataset
# The `tips` dataset is another built-in dataset in seaborn, containing information about restaurant tips. It is commonly used for data visualization practice.
# **Example:**
# ```python
# df1 = sns.load_dataset('tips')
# df1.head()  # Display the first few rows
# ```

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Displaying the Tips DataFrame
# This cell displays the loaded `tips` DataFrame, allowing you to inspect the first few rows and understand the structure of the data.
# **Example:**
# ```python
# df1.head()  # Show the first 5 rows of the tips dataset
# ```

# %%
sns.relplot(df1,x='total_bill',y='tip')

# %% [markdown]
# ## Relational Plot: Total Bill vs Tip
# A relational plot (relplot) visualizes the relationship between two variables. Here, we plot `total_bill` against `tip` to see how the tip amount varies with the bill.
# **Example:**
# ```python
# sns.relplot(df1, x='total_bill', y='tip')
# ```
# - Each point represents a restaurant bill and its corresponding tip.

# %%
df1['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %% [markdown]
# ## Counting Smokers in the Dataset
# This cell counts the number of smokers and non-smokers in the tips dataset using the `value_counts()` method.
# **Example:**
# ```python
# df1['smoker'].value_counts()
# ```
# - Helps understand the distribution of smokers in the dataset.

# %%
sns.scatterplot(df1,x='total_bill',y='tip',hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Scatter Plot: Total Bill vs Tip by Smoker Status
# This scatter plot visualizes the relationship between total bill and tip, with points colored by smoker status.
# **Example:**
# ```python
# sns.scatterplot(df1, x='total_bill', y='tip', hue='smoker')
# ```
# - Each point represents a bill and tip, colored by whether the customer was a smoker.

# %%
sns.relplot(df1,x='total_bill',y='tip',hue='smoker')

# %% [markdown]
# ## Relational Plot: Total Bill vs Tip by Smoker
# This relational plot shows the relationship between total bill and tip, with points colored by smoker status.
# **Example:**
# ```python
# sns.relplot(df1, x='total_bill', y='tip', hue='smoker')
# ```
# - Useful for comparing tipping behavior between smokers and non-smokers.

# %%
sns.relplot(df1,x='total_bill',y='tip',hue='smoker',col='time')

# %% [markdown]
# ## Relational Plot by Smoker and Time
# This plot splits the data into separate columns based on the `time` of day (Lunch or Dinner), and colors points by smoker status.
# **Example:**
# ```python
# sns.relplot(df1, x='total_bill', y='tip', hue='smoker', col='time')
# ```
# - Each subplot shows the relationship for a different time of day.

# %%
sns.relplot(df1,x='total_bill',y='tip',style='time',hue='smoker',col='day')

# %% [markdown]
# ## Relational Plot by Smoker, Time, and Day
# This plot uses different marker styles for time of day, colors for smoker status, and splits the data into columns by day of the week.
# **Example:**
# ```python
# sns.relplot(df1, x='total_bill', y='tip', style='time', hue='smoker', col='day')
# ```
# - Each subplot shows a different day, with marker style for time and color for smoker.

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(df1,x='total_bill',y='tip',size='size',hue='smoker',col='day',style='time')

# %% [markdown]
# ## Relational Plot with Size, Hue, Columns, and Style
# This plot visualizes the relationship between total bill and tip, with point size representing party size, color for smoker status, columns for day, and marker style for time.
# **Example:**
# ```python
# sns.relplot(df1, x='total_bill', y='tip', size='size', hue='smoker', col='day', style='time')
# ```
# - Each subplot shows a different day, with marker size for party size, color for smoker, and style for time.

# %%
sns.relplot(df1,x='total_bill',y='tip',kind='line')

# %% [markdown]
# ## Line Plot with Seaborn relplot
# By setting `kind='line'`, you can create a line plot to visualize trends in the data. Here, we plot total bill vs tip as a line plot.
# **Example:**
# ```python
# sns.relplot(df1, x='total_bill', y='tip', kind='line')
# ```
# - Useful for visualizing trends or changes over a continuous variable.

# %%
sns.relplot(x='total_bill',y='tip',col='size',data=df1)

# %% [markdown]
# ## Relational Plot by Party Size
# This plot splits the data into columns based on the party size, showing the relationship between total bill and tip for each group size.
# **Example:**
# ```python
# sns.relplot(x='total_bill', y='tip', col='size', data=df1)
# ```
# - Each subplot shows a different party size.

# %%
sns.relplot(df1,x='total_bill',y='tip',hue='smoker' ,style='sex',col='sex')

# %% [markdown]
# ## Relational Plot by Sex and Smoker Status
# This plot splits the data into columns by sex, colors points by smoker status, and uses different marker styles for sex.
# **Example:**
# ```python
# sns.relplot(df1, x='total_bill', y='tip', hue='smoker', style='sex', col='sex')
# ```
# - Each subplot shows a different sex, with color for smoker and style for sex.

# %%
df1.groupby('sex')['size'].value_counts()
# Out:
# C:\Users\haida\AppData\Local\Temp\ipykernel_15396\493520211.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1.groupby('sex')['size'].value_counts()
# sex     size
# Male    2       98
#         4       28
#         3       24
#         5        4
#         6        2
#         1        1
# Female  2       58
#         3       14
#         4        9
#         1        3
#         6        2
#         5        1
# Name: count, dtype: int64

# %% [markdown]
# ## Grouping and Counting by Sex and Party Size
# This cell groups the data by sex and counts the occurrences of each party size.
# **Example:**
# ```python
# df1.groupby('sex')['size'].value_counts()
# ```
# - Useful for understanding the distribution of party sizes for each sex.

# %%
sns.relplot(df1,x='total_bill',y='tip',hue='sex',col='size',)

# %% [markdown]
# ## Relational Plot by Sex and Party Size
# This plot splits the data into columns by party size and colors points by sex.
# **Example:**
# ```python
# sns.relplot(df1, x='total_bill', y='tip', hue='sex', col='size')
# ```
# - Each subplot shows a different party size, with color for sex.

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Displaying the Tips DataFrame Again
# This cell displays the `tips` DataFrame, which can be useful for reference after performing several analyses.
# **Example:**
# ```python
# df1.head()
# ```

# %%
sns.barplot(x='day',y='total_bill',data=df1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Bar Plot: Total Bill by Day
# A bar plot shows the average total bill for each day of the week. This helps compare spending patterns across different days.
# **Example:**
# ```python
# sns.barplot(x='day', y='total_bill', data=df1)
# ```
# - Each bar represents the mean total bill for a day.

# %%
sns.catplot(x='day',y='total_bill',data=df1)

# %% [markdown]
# ## Categorical Plot: Total Bill by Day
# A categorical plot (catplot) is a general plot for categorical data. Here, it shows the distribution of total bills for each day.
# **Example:**
# ```python
# sns.catplot(x='day', y='total_bill', data=df1)
# ```
# - Useful for visualizing the spread and central tendency of total bills by day.

# %%
sns.catplot(x='day',y='tip',data=df1)

# %% [markdown]
# ## Categorical Plot: Tip by Day
# This categorical plot shows the distribution of tips for each day of the week.
# **Example:**
# ```python
# sns.catplot(x='day', y='tip', data=df1)
# ```
# - Useful for comparing tipping patterns across days.

# %%
sns.catplot(x='day',y='total_bill',data=df1,kind='swarm')

# %% [markdown]
# ## Swarm Plot: Total Bill by Day
# A swarm plot shows all data points for a categorical variable, avoiding overlap. Here, it displays total bills for each day.
# **Example:**
# ```python
# sns.catplot(x='day', y='total_bill', data=df1, kind='swarm')
# ```
# - Each point represents a bill, and points are spread out to avoid overlap.

# %%
sns.catplot(x='day',y='tip',data=df1,kind='box' ,hue='smoker')

# %% [markdown]
# ## Box Plot: Tip by Day and Smoker Status
# A box plot summarizes the distribution of a variable, showing the median, quartiles, and outliers. Here, it shows tips by day, with color for smoker status.
# **Example:**
# ```python
# sns.catplot(x='day', y='tip', data=df1, kind='box', hue='smoker')
# ```
# - Each box shows the distribution of tips for a day, split by smoker status.

# %%
sns.pairplot(df, hue='species')

# %% [markdown]
# ## Pairplot: Visualizing Pairwise Relationships in Iris Dataset
# A pairplot creates scatter plots for each pair of numerical features, colored by a categorical variable. Here, it shows all pairwise relationships in the iris dataset, colored by species.
# **Example:**
# ```python
# sns.pairplot(df, hue='species')
# ```
# - Useful for visualizing relationships and clusters in multivariate data.

# %%
sns.pairplot(df1, hue='smoker')

# %% [markdown]
# ## Pairplot: Visualizing Pairwise Relationships in Tips Dataset
# This pairplot shows all pairwise relationships in the tips dataset, colored by smoker status.
# **Example:**
# ```python
# sns.pairplot(df1, hue='smoker')
# ```
# - Useful for exploring relationships and clusters in the data.

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %% [markdown]
# ## Importing Cufflinks for Interactive Plotting
# Cufflinks connects pandas to Plotly, enabling interactive plotting directly from DataFrames. `cf.go_offline()` allows you to use Plotly without an internet connection.
# **Example:**
# ```python
# import cufflinks as cf
# cf.go_offline()
# ```

# %%
titanic = sns.load_dataset("titanic")

# %% [markdown]
# ## Loading the Titanic Dataset
# The Titanic dataset is a classic dataset containing information about passengers on the Titanic. It is often used for data analysis and visualization practice.
# **Example:**
# ```python
# titanic = sns.load_dataset('titanic')
# titanic.head()  # Display the first few rows
# ```

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Displaying the Titanic DataFrame
# This cell displays the loaded Titanic DataFrame, allowing you to inspect the first few rows and understand the structure of the data.
# **Example:**
# ```python
# titanic.head()  # Show the first 5 rows of the Titanic dataset
# ```

# %%
import plotly.express as px
fig1 = px.bar(titanic,x='sex',y='survived',barmode='group',height=400)
fig1.show()
titanic.groupby('sex')['survived'].value_counts()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Bar Plot: Survival by Sex with Plotly Express
# This code uses Plotly Express to create an interactive bar plot showing the number of survivors by sex on the Titanic. The grouped bar mode allows comparison between groups.
# **Example:**
# ```python
# import plotly.express as px
# fig1 = px.bar(titanic, x='sex', y='survived', barmode='group', height=400)
# fig1.show()
# ```
# - The grouped bars show the number of survivors for each sex.
