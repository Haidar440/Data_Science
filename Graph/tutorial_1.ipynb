# %% [markdown]
# # Data Visualization and Analysis with pandas, numpy, and matplotlib
# This notebook demonstrates how to use pandas, numpy, and matplotlib for data analysis and visualization. Each code cell is preceded by a markdown cell explaining its purpose and the functions used.
#
# ## Importing Required Libraries
# The following code imports numpy for numerical operations, matplotlib for plotting, and pandas for data manipulation.
# **Example:**
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# ```

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# ## Interactive Plotting with Cufflinks and Plotly
# The `df.iplot()` function from the cufflinks library creates interactive plots using Plotly. This allows you to explore your data visually with zoom, pan, and hover features.
# **Example:**
# ```python
# import cufflinks as cf
# cf.go_offline()
# df.iplot()  # Interactive line plot of all columns
# ```
# **Note:** Only use valid color strings if you want to customize colors.

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['Data'],index=pd.date_range('21/7/2025',periods=1000))
df
# Out:
#                 Data
# 2025-07-21 -0.210969
# 2025-07-22 -1.788668
# 2025-07-23 -0.347383
# 2025-07-24  1.243033
# 2025-07-25 -0.466241
# ...              ...
# 2028-04-11  0.244950
# 2028-04-12 -0.547816
# 2028-04-13 -0.874670
# 2028-04-14 -0.593417
# 2028-04-15  0.684728
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Setting pandas Plotting Backend to Plotly
# You can set pandas to use Plotly as the default plotting backend. This allows you to use pandas' plot functions with interactive Plotly charts.
# **Example:**
# ```python
# pd.options.plotting.backend = "plotly"
# df.plot()  # Now uses Plotly for plotting
# ```
# **Note:** If you use cufflinks' `iplot()`, you do not need to set this backend.

# %% [markdown]
# ## Creating a DataFrame with Random Data and Date Index
# This code creates a DataFrame with 1000 rows of random numbers using `np.random.randn`, sets the column name to 'Data', and uses a date range as the index.
# **Example:**
# ```python
# df = pd.DataFrame(np.random.randn(1000), columns=['Data'], index=pd.date_range('2025-07-21', periods=1000))
# df.head()  # Shows the first 5 rows
# ```

# %%
df.plot(figsize=(15,8), title='Random Data Plot')
# Out:
# <Axes: title={'center': 'Random Data Plot'}>

# %% [markdown]
# ## Plotting the DataFrame
# This code uses the `plot()` method to visualize the DataFrame. The `figsize` parameter sets the plot size, and `title` adds a title to the plot.
# **Example:**
# ```python
# df.plot(figsize=(15,5), title='Random Data Plot')
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df = pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Loading the Iris Dataset from a CSV URL
# This code loads the famous Iris dataset from a CSV file hosted online using `pd.read_csv`. Displaying `df` shows the loaded data.
# **Example:**
# ```python
# df = pd.read_csv('https://.../iris.csv')
# df.head()  # Shows the first 5 rows
# ```

# %%
df.plot(figsize=(15,8),title='Random Data Plot')
# Out:
# <Axes: title={'center': 'Random Data Plot'}>

# %% [markdown]
# ## Plotting the Iris DataFrame
# This code plots the iris DataFrame using the `plot()` method. The `figsize` parameter sets the plot size, and `title` adds a title to the plot.
# **Example:**
# ```python
# df.plot(figsize=(15,8), title='Iris Data Plot')
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %% [markdown]
# ## Selecting Rows by Index Using iloc
# This code selects rows 5 to 10 (inclusive of 5, exclusive of 11) from the DataFrame using `iloc`, which allows integer-based indexing and slicing.
# **Example:**
# ```python
# df.iloc[5:11]  # Selects rows 5 to 10
# ```

# %%
df.iloc[5:11].plot(kind='bar',figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting Selected Rows as a Bar Chart
# This code plots the selected rows (5 to 10) as a bar chart using the `plot()` method with `kind='bar'`. The `figsize` parameter sets the plot size.
# **Example:**
# ```python
# df.iloc[5:11].plot(kind='bar', figsize=(15,5))
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.iloc[[5]].plot(kind='bar',figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting a Single Row as a Vertical Bar Chart
# This code selects a single row (row 5) using `iloc[[5]]` and plots it as a vertical bar chart using `plot(kind='bar')`.
# **Example:**
# ```python
# df.iloc[[5]].plot(kind='bar', figsize=(15,5))
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df.iloc[[5]].plot(kind='barh',figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting a Single Row as a Horizontal Bar Chart
# This code selects a single row (row 5) using `iloc[[5]]` and plots it as a horizontal bar chart using `plot(kind='barh')`.
# **Example:**
# ```python
# df.iloc[[5]].plot(kind='barh', figsize=(15,5))
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Plotting a Histogram for All Columns
# A **histogram** is a plot that shows the distribution of a numerical variable by dividing the data into bins and displaying the frequency of values in each bin. This helps you see how your data is spread out, whether it is centered, skewed, or has outliers.
#
# The following code plots a histogram for all numerical columns in the DataFrame:
# ```python
# df.plot(kind='hist')
# ```
# - Each bar represents the number of data points in a specific range (bin) for each column.
# - Useful for visualizing the overall distribution of your dataset.

# %%
df['sepal_length'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Plotting a Histogram for Sepal Length
# A **histogram** is a graphical representation that shows the distribution of a numerical variable by dividing the data into bins and displaying the frequency of values in each bin. It helps you understand how your data is spread out and whether it is skewed, centered, or has outliers.
#
# The following code plots a histogram for the `sepal_length` column in the Iris dataset:
# ```python
# df['sepal_length'].plot(kind='hist')
# ```
# - Each bar represents the number of flowers with sepal lengths in a specific range.
# - Taller bars mean more flowers have sepal lengths in that range.
# - This helps you quickly see if most sepal lengths are short, long, or somewhere in between.

# %%
df.hist(figsize=(15,8),color='g',bins=20,alpha=1)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# ## Visualizing Distributions with DataFrame.hist()
# The `df.hist()` function creates histograms for each numerical column in the DataFrame. This helps you visualize the distribution of each variable at once.
#
# **Parameters used:**
# - `figsize=(15,8)`: Sets the size of the entire figure.
# - `color='g'`: Sets the color of the bars to green.
# - `bins=20`: Divides the data into 20 intervals (bins).
# - `alpha=1`: Sets the opacity of the bars (1 means fully opaque).
#
# **Example:**
# ```python
# df.hist(figsize=(15,8), color='g', bins=20, alpha=1)
# ```
# This will show a grid of histograms, one for each numeric column in your DataFrame.

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Visualizing Data Distribution with a Box Plot
# A **box plot** (or box-and-whisker plot) is a graphical representation that shows the distribution, spread, and outliers of numerical data. It displays the median, quartiles, and possible outliers for each column.
#
# The following code creates a box plot for all numerical columns in the DataFrame:
# ```python
# df.plot(kind='box', figsize=(15,8), title='Box Plot of Iris Dataset')
# ```
# - The box shows the interquartile range (middle 50% of the data).
# - The line inside the box is the median (middle value).
# - Whiskers show the range of the data, except for outliers.
# - Dots outside the whiskers represent outliers.
#
# Box plots are useful for comparing distributions and spotting outliers in your data.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Descriptive Statistics with DataFrame.describe()
# The `df.describe()` function generates summary statistics for each numerical column in the DataFrame. It provides useful information such as:
# - **count**: Number of non-null values
# - **mean**: Average value
# - **std**: Standard deviation (spread of the data)
# - **min**: Minimum value
# - **25%**: First quartile (25% of data below this value)
# - **50%**: Median (middle value)
# - **75%**: Third quartile (75% of data below this value)
# - **max**: Maximum value
#
# This helps you quickly understand the central tendency, spread, and shape of your data.

# %%
df.plot(kind='area',figsize=(15,8),title='Area Plot of Iris Dataset')
# Out:
# <Axes: title={'center': 'Area Plot of Iris Dataset'}>

# %% [markdown]
# ## Visualizing Data with an Area Plot
# An **area plot** displays quantitative data graphically, showing the magnitude of values over a continuous interval or time period. It is similar to a line plot, but the area between the line and the axis is filled with color, making it easy to compare multiple variables.
#
# The following code creates an area plot for all numeric columns in the DataFrame:
# ```python
# df.plot(kind='area', figsize=(15,8), title='Area Plot of Iris Dataset')
# ```
# - Each colored area represents a column's values over the index (e.g., row number or date).
# - Useful for visualizing cumulative totals or comparing trends between columns.

# %%
df.plot(kind = 'area' , figsize = (20,10),stacked = False)
# Out:
# <Axes: >

# %% [markdown]
# ## Creating a Non-Stacked Area Plot
# By default, area plots are stacked, meaning each column's area is drawn on top of the previous one. Setting `stacked=False` creates a non-stacked area plot, where each column's area is independent, making it easier to compare trends.
#
# **Example:**
# ```python
# df.plot(kind='area', figsize=(20,10), stacked=False)
# ```
# - Each colored area represents a column's values, not stacked on top of each other.

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ## Visualizing Relationships with a Scatter Plot
# A **scatter plot** displays values for two numeric variables as points on a Cartesian plane. It helps you see the relationship or correlation between the variables.
#
# The following code creates a scatter plot of `sepal_length` vs. `petal_length`:
# ```python
# df.plot.scatter(x='sepal_length', y='petal_length')
# ```
# - Each point represents a row in the DataFrame.
# - Useful for visualizing trends, clusters, and outliers.

# %%
df.plot.scatter(x='sepal_length',y='petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %% [markdown]
# ## Scatter Plot: Sepal Length vs Petal Width
# This scatter plot visualizes the relationship between `sepal_length` and `petal_width` for each sample in the dataset.
#
# **Example:**
# ```python
# df.plot.scatter(x='sepal_length', y='petal_width')
# ```
# - Each point represents a flower.
# - Useful for identifying patterns or correlations between these two features.

# %%
df.plot.scatter(x='sepal_length',y='petal_length',figsize=(15,8),title='Scatter Plot of Iris Dataset',c='sepal_width',
                s= df['sepal_width']*20)
# Out:
# <Axes: title={'center': 'Scatter Plot of Iris Dataset'}, xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ## Advanced Scatter Plot with Color and Size Encoding
# This scatter plot visualizes `sepal_length` vs. `petal_length`, with point color and size representing `sepal_width`. This adds more dimensions to the plot, making it easier to spot patterns.
#
# **Example:**
# ```python
# df.plot.scatter(x='sepal_length', y='petal_length', figsize=(15,8), title='Scatter Plot of Iris Dataset', c='sepal_width', s=df['sepal_width']*20)
# ```
# - `c='sepal_width'`: Colors points by sepal width.
# - `s=df['sepal_width']*20`: Sets point size based on sepal width.
# - Useful for visualizing three variables at once.

# %%
df.plot.hexbin(x='sepal_length', y='petal_length', gridsize=10, cmap='Greens',C='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ## Visualizing Density with a Hexbin Plot
# A **hexbin plot** is used to visualize the density of points in a scatter plot, especially for large datasets. It divides the plot area into hexagons and colors them based on the number of points in each hexagon.
#
# The following code creates a hexbin plot of `sepal_length` vs. `petal_length`, with color intensity based on `sepal_width`:
# ```python
# df.plot.hexbin(x='sepal_length', y='petal_length', gridsize=10, cmap='Greens', C='sepal_width')
# ```
# - `gridsize=10`: Sets the number of hexagons in the x-direction.
# - `cmap='Greens'`: Sets the color map.
# - `C='sepal_width'`: Colors hexagons by the average sepal width in each bin.
# - Useful for visualizing point density and relationships in large datasets.

# %%
# Plot a pie chart for the first row's numeric values (excluding 'species')
df.iloc[0][['sepal_length', 'sepal_width', 'petal_length', 'petal_width',]].plot(
	kind='pie', autopct='%1.1f%%', figsize=(8, 8), title='Pie Chart of First Row (Numeric Features)'
)
# Out:
# C:\Users\haida\AppData\Local\Temp\ipykernel_20104\3458748009.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.iloc[0][['sepal_length', 'sepal_width', 'petal_length', 'petal_width',]].plot(
# <Axes: title={'center': 'Pie Chart of First Row (Numeric Features)'}, ylabel='0'>

# %% [markdown]
# ## Visualizing Proportions with a Pie Chart
# A **pie chart** shows the proportion of each value as a slice of a circle. It is useful for visualizing the relative sizes of parts to a whole.
#
# The following code creates a pie chart for the first row's numeric features:
# ```python
# # Plot a pie chart for the first row's numeric values (excluding 'species')
# df.iloc[0][['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].plot(
# kind='pie', autopct='%1.1f%%', figsize=(8, 8), title='Pie Chart of First Row (Numeric Features)'
# )
# ```
# - `autopct='%1.1f%%'`: Shows percentage values on the chart.
# - `figsize=(8, 8)`: Sets the size of the plot.
# - Useful for visualizing the composition of a single observation.

# %%
df1 = df.drop(columns=['species']).iloc[0]

# %% [markdown]
# ## Creating a Series for a Single Row
# This code selects the first row of the DataFrame (excluding the 'species' column) and stores it as a pandas Series. This is useful for plotting or analyzing a single observation.
#
# **Example:**
# ```python
# df1 = df.drop(columns=['species']).iloc[0]  # Selects the first row as a Series
# df1
# ```

# %%
df1.plot(kind='pie', subplots=True, figsize=(15, 8), autopct='%1.1f%%', title='Pie Chart of Iris Dataset Features')
# Out:
# array([<Axes: ylabel='0'>], dtype=object)

# %% [markdown]
# ## Plotting a Pie Chart for a Series
# This code creates a pie chart for the values in a pandas Series (e.g., a single row of features).
# **Example:**
# ```python
# df1.plot(kind='pie', subplots=True, figsize=(15, 8), autopct='%1.1f%%', title='Pie Chart of Iris Dataset Features')
# ```
# - `subplots=True`: Plots each value as a separate subplot (for a Series, this is just one plot).
# - `autopct='%1.1f%%'`: Shows percentage values.
# - Useful for visualizing the composition of a single observation.

# %%
# !pip install cufflinks
# !pip install plotly
# Out:
# ...
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# ...
#   Using cached plotly-6.3.0-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Using cached plotly-6.3.0-py3-none-any.whl (9.8 MB)
# ...
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# ...
#
#    ---------------------------------------- 0/8 [colorlover]
#    ----- ---------------------------------- 1/8 [widgetsnbextension]
# ...

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %%
df2 = df.drop(columns=['species'], axis=1)
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
import plotly.express as px
fig_line = px.line(df2, title="Iris Dataset Line Plot")
fig_line.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 3
#       1 import plotly.express as px
#       2 fig_line = px.line(df2, title="Iris Dataset Line Plot")
# ----> 3 fig_line.show()
#
# File d:\Data_Science\.venv\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File d:\Data_Science\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
# ...

# %% [markdown]
# ## Interactive Plotting with Cufflinks and Plotly
# The `df.iplot()` function from the cufflinks library creates interactive plots using Plotly. It works best with default arguments. If you want to customize colors, use valid CSS color strings (e.g., `'rgb(255,153,51)'` or `'#ff9933'`).
# **Note:** Avoid passing numpy or pandas objects as color arguments. Only use valid color strings as described in the [Plotly documentation](https://plotly.com/python/css-colors/).
# **Example:**
# ```python
# df.iplot()  # Interactive line plot of all columns
# ```

# %% [markdown]
# ## Creating Interactive Line Plots with Plotly Express
# Plotly Express (`px`) is a high-level interface for creating interactive plots. You can use `px.line()` to plot one or more numeric columns from your DataFrame.
# **Example:**
# ```python
# import plotly.express as px
# numeric_cols = df.select_dtypes(include='number').columns
# fig = px.line(df, y=numeric_cols, title="Line Plot with Plotly Express")
# fig.show()
# ```
# - This will create an interactive line plot for all numeric columns in your DataFrame.

# %%
fig2 = px.scatter(df,x='sepal_length', y='petal_length', title="Iris Dataset Scatter Plot", )
fig2.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Plotly Express does not have a 'bubble' function. Use px.scatter with 'size' for bubble plots.
fig2 = px.scatter(
	df,
	x='sepal_length',
	y='petal_length',
	size='sepal_width',  # Bubble size
	title="Iris Dataset Bubble Plot"
)
fig2.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = px.scatter_3d(
	df,
	x='sepal_length',
	y='sepal_width',
    z='petal_length',
	size='sepal_width',  # Bubble size
	title="Iris Dataset Bubble Plot"
)
fig2.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig2 = px.scatter_3d(
    df.head(),
    x='sepal_length',
    y='sepal_width',
    z='petal_length',
    size='sepal_width',  # Bubble size
    title="Iris Dataset Bubble Plot",
    color_discrete_sequence=['orange']  # Set all points to orange
)
fig2.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
