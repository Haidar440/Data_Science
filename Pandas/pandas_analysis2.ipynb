# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis=1, thresh=800)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.dropna(axis=0, how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value="Haidar")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex     Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0      1
# 2                               Heikkinen, Miss. Laina  female    26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0      1
# 4                             Allen, Mr. William Henry    male    35.0      0
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.fillna(value={"Age":df['Age'].mean()})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()["PassengerId"]
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
df.groupby('Survived').describe().transpose()
df.groupby('Survived').describe().T
# Out:
# Survived                    0           1
# PassengerId count  549.000000  342.000000
#             mean   447.016393  444.368421
#             std    260.640469  252.358840
#             min      1.000000    2.000000
#             25%    211.000000  250.750000
#             50%    455.000000  439.500000
#             75%    675.000000  651.500000
#             max    891.000000  890.000000
# Pclass      count  549.000000  342.000000
#             mean     2.531876    1.950292
#             std      0.735805    0.863321
#             min      1.000000    1.000000
#             25%      2.000000    1.000000
#             50%      3.000000    2.000000
#             75%      3.000000    3.000000
#             max      3.000000    3.000000
# Age         count  424.000000  290.000000
#             mean    30.626179   28.343690
#             std     14.172110   14.950952
#             min      1.000000    0.420000
#             25%     21.000000   19.000000
# ...

# %%
df_bank = pd.read_csv("bank.csv",sep=';')
df_bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
for i in df_bank['education'].unique():
    globals()[i] = df_bank[df_bank['education']==i]

# %%
primary.head()
# Out:
#     age          job   marital education default  balance housing loan  \
# 0    30   unemployed   married   primary      no     1787      no   no
# 9    43     services   married   primary      no      -88     yes  yes
# 18   25  blue-collar    single   primary      no     -221     yes   no
# 26   55  blue-collar   married   primary      no      627     yes   no
# 36   78      retired  divorced   primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# 9    cellular   17   apr       313         1    147         2  failure   no
# 18    unknown   23   may       250         1     -1         0  unknown   no
# 26    unknown    5   may       247         1     -1         0  unknown   no
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
secondary.head()
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
# Let's try Concatenation of DataFrames Row Wise

df_concat = pd.concat([primary.head(),secondary.head()])

df_concat
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0    30   unemployed   married    primary      no     1787      no   no
# 9    43     services   married    primary      no      -88     yes  yes
# 18   25  blue-collar    single    primary      no     -221     yes   no
# 26   55  blue-collar   married    primary      no      627     yes   no
# 36   78      retired  divorced    primary      no      229      no   no
# 1    33     services   married  secondary      no     4789     yes  yes
# 4    59  blue-collar   married  secondary      no        0     yes   no
# 7    39   technician   married  secondary      no      147     yes   no
# 10   39     services   married  secondary      no     9374     yes   no
# 11   43       admin.   married  secondary      no      264     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# ...

# %%
# Now let's look at Column-wise Concatenation


primary_col = primary.head()[['age', 'job','marital']]
secondary_col = secondary.head()[['age', 'job','marital']]
df_concat_col = pd.concat([primary_col,secondary_col], axis=1)

df_concat_col
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 9   43.0     services   married   NaN          NaN      NaN
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married

# %%
df_concat_col['age'] #It's Create an issue where is duplicated column names and fetch both columns
# Out:
#      age   age
# 0   30.0   NaN
# 9   43.0   NaN
# 18  25.0   NaN
# 26  55.0   NaN
# 36  78.0   NaN
# 1    NaN  33.0
# 4    NaN  59.0
# 7    NaN  39.0
# 10   NaN  39.0
# 11   NaN  43.0

# %%
df_concat_col.iloc[:,3] #Now we can access the duplicated 'age' columns using iloc
# Out:
# 0      NaN
# 9      NaN
# 18     NaN
# 26     NaN
# 36     NaN
# 1     33.0
# 4     59.0
# 7     39.0
# 10    39.0
# 11    43.0
# Name: age, dtype: float64

# %%
#Let's Understand about iloc briefly
# iloc is primarily integer-location based indexing
# It allows you to select rows and columns by their integer positions
# It is useful when you want to access specific rows and columns without relying on their labels
# Syntax:
# iloc[row_indices, column_indices]
# For example:
# iloc[7,5] Access for Particular value From row 7 and column 5


df_concat_col.iloc[7,1]
# Out:
# nan

# %%
#  iloc[[7,8],[5,6]] Select Rows and Columns What You define
df_concat_col.iloc[[7,8],[1,2]] #Select Rows and Columns What You define
# Out:
#     job marital
# 7   NaN     NaN
# 10  NaN     NaN

# %%
# iloc[:5,:3] It's like Range where define starting and ending of Rows and Columns
df_concat_col.iloc[:5,:3] #It's like Range where define starting and ending of Rows and Columns
# Out:
#      age          job   marital
# 0   30.0   unemployed   married
# 9   43.0     services   married
# 18  25.0  blue-collar    single
# 26  55.0  blue-collar   married
# 36  78.0      retired  divorced

# %%
#Let's understand about loc
# loc is primarily label-based indexing
# It allows you to select rows and columns by their labels
# It is useful when you want to access specific rows and columns using their names
# Syntax:
# loc[row_labels, column_labels]
# For example:
# loc['row_label', 'column_label']
# loc[['row1', 'row2'], ['col1', 'col2']] Select Rows and Columns What You define
# loc[:'row5', :'col3'] It's like Range where define starting and ending of Rows and Columns
df_concat_col.loc[9, 'job'] # Access for particular value from row 9 and columns 'job' and 'marital'
# Out:
# job    services
# job         NaN
# Name: 9, dtype: object

# %%
df_concat_col.loc[9, ['job', 'marital']].iloc[[0, 2]]
# Out:
# job        services
# marital     married
# Name: 9, dtype: object

# %%
# df_concat_col.loc[['row1', 'row2'], ['col1', 'col2']] #Select Rows and Columns What You define
df_concat_col.loc[[7, 0], ['job', 'marital']] #Select Rows and Columns What You define
# Out:
#           job         job  marital  marital
# 7         NaN  technician      NaN  married
# 0  unemployed         NaN  married      NaN

# %%
df2 = df_concat.head()[['age', 'job', 'marital']]

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.loc[[9,18], ['age', 'job']]
# Out:
#     age          job
# 9    43     services
# 18   25  blue-collar

# %%
df2.iloc[[1,2],[0,1]]
# Out:
#     age          job
# 9    43     services
# 18   25  blue-collar

# %%
df3 = secondary_col.head()[['age', 'job', 'marital']]
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
pd.merge(df2,df3,on='age')
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
pd.merge(df2,df3,on='job') #Merge works to check where job match between df2 and df3
#It like as Sql inner join
# Out:
#    age_x          job marital_x  age_y marital_y
# 0     43     services   married     33   married
# 1     43     services   married     39   married
# 2     25  blue-collar    single     59   married
# 3     55  blue-collar   married     59   married

# %%
pd.merge(df2,df3,on='age',how='left') #Left join will keep all records from df2 and match with df3
# But unmatched records from df3 will have NaN in the result
# Out:
#    age        job_x marital_x   job_y marital_y
# 0   30   unemployed   married     NaN       NaN
# 1   43     services   married  admin.   married
# 2   25  blue-collar    single     NaN       NaN
# 3   55  blue-collar   married     NaN       NaN
# 4   78      retired  divorced     NaN       NaN

# %%
pd.merge(df2, df3, on='age', how='inner') #Inner join will keep only matching records from both df2 and df3
# It will not include any records from either dataframe that do not have a match
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
pd.merge(df2, df3, on='age', how='right') #Right join will keep all records from df3 and match with df2
# But unmatched records from df2 will have NaN in the result
# Out:
#    age     job_x marital_x        job_y marital_y
# 0   33       NaN       NaN     services   married
# 1   59       NaN       NaN  blue-collar   married
# 2   39       NaN       NaN   technician   married
# 3   39       NaN       NaN     services   married
# 4   43  services   married       admin.   married

# %%
df2_index = df2.set_index("age")
df2_index.rename(columns={'job': 'occupation','marital':'status'}, inplace=True)
df2_index
# Out:
#       occupation    status
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df3_index = df3.set_index("age")
df3_index
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df2_index.join(df3_index, on='age',how='inner') #Inner join will keep only matching records from both df2 and df3
#But Join Method is similar to merge but it works on index
#It can be more efficient than merge for large datasets
#It avoids the overhead of aligning the dataframes by their columns
# Out:
#     occupation   status     job  marital
# age
# 43    services  married  admin.  married

# %%
df2_index.join(df3_index) #Inner join using index
# Out:
#       occupation    status     job  marital
# age
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 25   blue-collar    single     NaN      NaN
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
pd.merge(df2_index,df3_index,left_on = 'occupation',right_on = 'job')
# Out:
#     occupation   status          job  marital
# 0     services  married     services  married
# 1     services  married     services  married
# 2  blue-collar   single  blue-collar  married
# 3  blue-collar  married  blue-collar  married

# %%
# df2[df2['age'].reset_index(drop=True) >= df3['age'].reset _index(drop=True)]
# Reset index for both DataFrames to align them for element-wise comparison
df2_reset = df2.reset_index(drop=True)
df3_reset = df3.reset_index(drop=True)

# Compare the 'age' columns and filter rows from df2 where df2['age'] >= df3['age']
df2_reset[df2_reset['age'] >= df3_reset['age']]
df2_index
# Out:
#       occupation    status
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced
