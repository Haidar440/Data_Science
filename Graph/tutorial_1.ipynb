# %% [markdown]
# # Data Visualization and Analysis with pandas, numpy, and matplotlib
# This notebook demonstrates how to use pandas, numpy, and matplotlib for data analysis and visualization. Each code cell is preceded by a markdown cell explaining its purpose and the functions used.
#
# ## Importing Required Libraries
# The following code imports numpy for numerical operations, matplotlib for plotting, and pandas for data manipulation.
# **Example:**
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# ```

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['Data'],index=pd.date_range('21/7/2025',periods=1000))
df
# Out:
#                 Data
# 2025-07-21  0.154869
# 2025-07-22 -0.262766
# 2025-07-23  1.760631
# 2025-07-24 -0.686929
# 2025-07-25  0.418839
# ...              ...
# 2028-04-11  1.445092
# 2028-04-12  0.171560
# 2028-04-13  0.956045
# 2028-04-14  1.465872
# 2028-04-15  0.608655
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Creating a DataFrame with Random Data and Date Index
# This code creates a DataFrame with 1000 rows of random numbers using `np.random.randn`, sets the column name to 'Data', and uses a date range as the index.
# **Example:**
# ```python
# df = pd.DataFrame(np.random.randn(1000), columns=['Data'], index=pd.date_range('2025-07-21', periods=1000))
# df.head()  # Shows the first 5 rows
# ```

# %%
df.plot(figsize=(15,5),title='Random Data Plot')
# Out:
# <Axes: title={'center': 'Random Data Plot'}>

# %% [markdown]
# ## Plotting the DataFrame
# This code uses the `plot()` method to visualize the DataFrame. The `figsize` parameter sets the plot size, and `title` adds a title to the plot.
# **Example:**
# ```python
# df.plot(figsize=(15,5), title='Random Data Plot')
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df = pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Loading the Iris Dataset from a CSV URL
# This code loads the famous Iris dataset from a CSV file hosted online using `pd.read_csv`. Displaying `df` shows the loaded data.
# **Example:**
# ```python
# df = pd.read_csv('https://.../iris.csv')
# df.head()  # Shows the first 5 rows
# ```

# %%
df.plot(figsize=(15,8),title='Random Data Plot')
# Out:
# <Axes: title={'center': 'Random Data Plot'}>

# %% [markdown]
# ## Plotting the Iris DataFrame
# This code plots the iris DataFrame using the `plot()` method. The `figsize` parameter sets the plot size, and `title` adds a title to the plot.
# **Example:**
# ```python
# df.plot(figsize=(15,8), title='Iris Data Plot')
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %% [markdown]
# ## Selecting Rows by Index Using iloc
# This code selects rows 5 to 10 (inclusive of 5, exclusive of 11) from the DataFrame using `iloc`, which allows integer-based indexing and slicing.
# **Example:**
# ```python
# df.iloc[5:11]  # Selects rows 5 to 10
# ```

# %%
df.iloc[5:11].plot(kind='bar',figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting Selected Rows as a Bar Chart
# This code plots the selected rows (5 to 10) as a bar chart using the `plot()` method with `kind='bar'`. The `figsize` parameter sets the plot size.
# **Example:**
# ```python
# df.iloc[5:11].plot(kind='bar', figsize=(15,5))
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.iloc[[5]].plot(kind='bar',figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting a Single Row as a Vertical Bar Chart
# This code selects a single row (row 5) using `iloc[[5]]` and plots it as a vertical bar chart using `plot(kind='bar')`.
# **Example:**
# ```python
# df.iloc[[5]].plot(kind='bar', figsize=(15,5))
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df.iloc[[5]].plot(kind='barh',figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting a Single Row as a Horizontal Bar Chart
# This code selects a single row (row 5) using `iloc[[5]]` and plots it as a horizontal bar chart using `plot(kind='barh')`.
# **Example:**
# ```python
# df.iloc[[5]].plot(kind='barh', figsize=(15,5))
# plt.show()  # Display the plot if running outside Jupyter
# ```

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Plotting a Histogram for All Columns
# A **histogram** is a plot that shows the distribution of a numerical variable by dividing the data into bins and displaying the frequency of values in each bin. This helps you see how your data is spread out, whether it is centered, skewed, or has outliers.
#
# The following code plots a histogram for all numerical columns in the DataFrame:
# ```python
# df.plot(kind='hist')
# ```
# - Each bar represents the number of data points in a specific range (bin) for each column.
# - Useful for visualizing the overall distribution of your dataset.

# %%
df['sepal_length'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Plotting a Histogram for Sepal Length
# A **histogram** is a graphical representation that shows the distribution of a numerical variable by dividing the data into bins and displaying the frequency of values in each bin. It helps you understand how your data is spread out and whether it is skewed, centered, or has outliers.
#
# The following code plots a histogram for the `sepal_length` column in the Iris dataset:
# ```python
# df['sepal_length'].plot(kind='hist')
# ```
# - Each bar represents the number of flowers with sepal lengths in a specific range.
# - Taller bars mean more flowers have sepal lengths in that range.
# - This helps you quickly see if most sepal lengths are short, long, or somewhere in between.

# %%
df.hist(figsize=(15,8),color='g',bins=20,alpha=1)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# ## Visualizing Distributions with DataFrame.hist()
# The `df.hist()` function creates histograms for each numerical column in the DataFrame. This helps you visualize the distribution of each variable at once.
#
# **Parameters used:**
# - `figsize=(15,8)`: Sets the size of the entire figure.
# - `color='g'`: Sets the color of the bars to green.
# - `bins=20`: Divides the data into 20 intervals (bins).
# - `alpha=1`: Sets the opacity of the bars (1 means fully opaque).
#
# **Example:**
# ```python
# df.hist(figsize=(15,8), color='g', bins=20, alpha=1)
# ```
# This will show a grid of histograms, one for each numeric column in your DataFrame.

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind='box',figsize=(15,8),title='Box Plot of Iris Dataset')
# Out:
# <Axes: title={'center': 'Box Plot of Iris Dataset'}>

# %% [markdown]
# ## Visualizing Data Distribution with a Box Plot
# A **box plot** (or box-and-whisker plot) is a graphical representation that shows the distribution, spread, and outliers of numerical data. It displays the median, quartiles, and possible outliers for each column.
#
# The following code creates a box plot for all numerical columns in the DataFrame:
# ```python
# df.plot(kind='box', figsize=(15,8), title='Box Plot of Iris Dataset')
# ```
# - The box shows the interquartile range (middle 50% of the data).
# - The line inside the box is the median (middle value).
# - Whiskers show the range of the data, except for outliers.
# - Dots outside the whiskers represent outliers.
#
# Box plots are useful for comparing distributions and spotting outliers in your data.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Descriptive Statistics with DataFrame.describe()
# The `df.describe()` function generates summary statistics for each numerical column in the DataFrame. It provides useful information such as:
# - **count**: Number of non-null values
# - **mean**: Average value
# - **std**: Standard deviation (spread of the data)
# - **min**: Minimum value
# - **25%**: First quartile (25% of data below this value)
# - **50%**: Median (middle value)
# - **75%**: Third quartile (75% of data below this value)
# - **max**: Maximum value
#
# This helps you quickly understand the central tendency, spread, and shape of your data.
